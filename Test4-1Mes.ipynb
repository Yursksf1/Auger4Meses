# %% [markdown]
# # Desarrollo de modelos predictivos para la estimación de la temperatura superficial de los detectores del observatorio Pierre Auger

# %% [markdown]
# ##  ** 1. Preparación de Datos **

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Definir nombres de las columnas que se van a usar y  la lista en la cual se van almacenar los dias de datos que se van a usar.**

# %%
nombres2=['fLsId', 'fTime', 'fPMT[0]', 'fPMT[1]', 'fPMT[2]', 'fElectT',
       'fBatteryT[0]', 'fBatteryT[1]'] 
indiceColumna=[0,1,14,15,16,17,18,19 ]
dias=[]
#0 fLsId
#1 fTime
#14 fPMT[0]
#15 fPMT[1]
#16 fPMT[2]
#17 fElectT
#18 fBatteryT[0]
#19 fBatteryT[1]

# %% [markdown]
# **Cargar los dias de datos necesarios**

# %%
dias.append(pd.read_csv("./0000mc_2014_05_01_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_02_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_03_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_04_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_05_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_07_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_08_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_09_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_10_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_11_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_12_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_13_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_14_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
dias.append(pd.read_csv("./0000mc_2014_05_15_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("./0000mc_2014_05_17_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("./0000mc_2014_05_18_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("./0000mc_2014_05_19_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("./0000mc_2014_05_20_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("./0000mc_2014_05_21_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("./0000mc_2014_05_22_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("0000mc_2014_05_23_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("0000mc_2014_05_24_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("0000mc_2014_05_25_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("0000mc_2014_05_26_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("0000mc_2014_05_27_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("0000mc_2014_05_28_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("0000mc_2014_05_29_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %%
#dias.append(pd.read_csv("0000mc_2014_05_30_00h00.root", header=None, names=nombres2, sep=" ", usecols=indiceColumna,index_col=1 ))

# %% [markdown]
# **Esta funcion permite seleccionar todos los registros en cada uno de los 19 detectores mas cercanos a una determinada estacion.La funcion retorna una lista de listas de dataframes **

# %%
listaLosleones=["321","440", "384", "441", "427", "379", "361", "429", "433",
                "385", "367", "432", "387", "346", "364", "376","375","360","383"]
#desechadosLeones=322[2],378[3]

listaLosmorados=["883", "673", "763", "874" ,"876" ,"877", "878", "879", "880","881","882","884" ,
                 "885","886","887","888","892","893","894"]


#desechadosMorados=
#listaLomaAmarilla=["1501", "1098", "1099", "1483", "1102", "1103", "1104" ,"1105", "1100", "1108",
#                   "1483","1115", "1116", "1117", "1118", "1119", "1120", "1126", "1164"]

listaLomaAmarilla=['1112','1105','1108','1127','1553','1478','1103','1131','1487','1110','1270',
                   '1347','1097','1133','1125','1369','1132','1284','1507']
#desechadosLomaAmarilla=1101[3],1109[10],1107[8] 1347,1119, 1100

listaCoihueco=["1827","1833", "1829","1831", "639", "601", "605", "607", "608",
 "609", "615", "786", "787", "1625", "1627", "1788", "1790", "1832","1847"]
#desechadosCoihueco=583[4]

# %%
def cantidadDetectores(numero):
    ll=listaLosleones[0:numero]
    lm=listaLosmorados[0:numero]
    la=listaLomaAmarilla[0:numero]
    lc=listaCoihueco[0:numero]
    return ll,lm,la,lc

# %%
def selectordeDetectores(listadeDetectores):
    listaDias =  [[] for key in listadeDetectores]
    for i in range(len(listadeDetectores)):
        for df in dias:
            df.index=pd.to_datetime(df.index,unit="s")
            listaDias[i].append(df[df.fLsId==int(listadeDetectores[i])])

    return listaDias

# %%
def anulador_datosPequeños(diasDetectores):
    corregidos=diasDetectores.copy()
    for i in range(len(diasDetectores)):
        for j in range(len(diasDetectores[0])):
            corregidos[i][j].is_copy = False
            corregidos[i][j].loc[corregidos[i][j]["fPMT[0]"]<0,"fPMT[0]"]=None
            corregidos[i][j].loc[corregidos[i][j]["fPMT[1]"]<0,"fPMT[1]"]=None
            corregidos[i][j].loc[corregidos[i][j]["fPMT[2]"]<0,"fPMT[2]"]=None
            corregidos[i][j].loc[corregidos[i][j]["fElectT"]<0,"fElectT"]=None
            corregidos[i][j].loc[corregidos[i][j]["fBatteryT[0]"]<0,"fBatteryT[0]"]=None
            corregidos[i][j].loc[corregidos[i][j]["fBatteryT[1]"]<0,"fBatteryT[1]"]=None
            corregidos[i][j].interpolate(inplace=True)
           
    return corregidos

# %%
ll,lm, la,lc =cantidadDetectores(5)
print(ll)
print(lm)
print(la)
print(lc)
# Out:
# ['321', '440', '384', '441', '427']
# ['883', '673', '763', '874', '876']
# ['1112', '1105', '1108', '1127', '1553']
# ['1827', '1833', '1829', '1831', '639']

# %%
diasLosLeones=selectordeDetectores(ll)
diasLosMorados=selectordeDetectores(lm)
diasLomaAmarilla=selectordeDetectores(la)
diasCoihueco=selectordeDetectores(lc)

# %%
diasLosLeones=anulador_datosPequeños(diasLosLeones)
diasLosMorados=anulador_datosPequeños(diasLosMorados)
diasLomaAmarilla=anulador_datosPequeños(diasLomaAmarilla)
diasCoihueco=anulador_datosPequeños(diasCoihueco)

# %%
def graficadorCrudo(diasStation,detector):
 
    for i in range(len(diasStation[0])):


        dias=diasStation[detector][i]
        id=str(dias.fLsId.iloc[0])
        temp=dias
        plt.figure(figsize=(15,4))
        x=temp.index
        y1=temp["fPMT[0]"]
        y2=temp["fPMT[1]"]
        y3=temp["fPMT[2]"]
        y4=temp["fElectT"]
        y5=temp["fBatteryT[0]"]
        y6=temp["fBatteryT[1]"]
        plt.plot(x,y1,label="fPMT[0]")
        plt.plot(x,y2, label="fPMT[1]")
        plt.plot(x,y3, label="fPMT[2]")
        plt.plot(x,y4, label="fElectT")
        plt.plot(x,y5, label="fBatteryT[0]")
        plt.plot(x,y6, label="fBatteryT[1]")
        #plt.plot(x,temp.Temperature,'k--', label="Temperature")
        plt.legend(loc='upper left', frameon=False)
        plt.title("Detector: "+id+"["+str(detector)+"]"+" Dias: "+str(i+1), fontsize=14, fontweight='bold')

# %%
graficadorCrudo(diasStation=diasLosLeones,detector=1)

# %%
 graficadorCrudo(diasStation=diasLosLeones,detector=0)

# %%
def deduplicadorV2(diasDetectores):
    deduplicado=diasDetectores
    for i in range(len(diasDetectores)):
        for j in range(len(diasDetectores[0])):
            deduplicado[i][j]=diasDetectores[i][j][~diasDetectores[i][j].index.duplicated(keep='first')]        
    return deduplicado

# %% [markdown]
# **Las siguientes instrucciones permiten imprimir en pantalla las dimensiones de los dataframes cuyos numero
# de registros no supera los 214 **

# %%
def contador(listaDias):
    for i in range(len(listaDias)):#19 detectores
        for j in range(len(listaDias[0])):#10 dias analizados
            if listaDias[i][j].shape[0]<214:
                print(listaDias[i][j].shape)

# %%
def contadorTotalRegistros(listaDias):
    sum=0
    for i in range(len(listaDias)):#19 detectores
        for j in range(len(listaDias[0])):#10 dias analizados
            sum=sum+listaDias[i][j].shape[0]
    print(sum)

# %%
def concatenadorResampler(detCercanos):
    detec=[[] for i in range(len(detCercanos))]
    for i in range(len(detCercanos)):
        detec[i]=pd.concat(detCercanos[i]).resample("400s").ffill()
    
    concatenado=pd.concat(detec, axis=1)
    concatenado.drop("fLsId", axis=1, inplace=True) #Se borra todas las columnas con el nombre fLsId
    return concatenado

# %% [markdown]
# Se hace el remuestreo en aras de garantizar los 216 registros(1 registro cada 400 segundos) por dia y de esta manera, evitar que cada registro de cada detector corresponda con los registros de los otros.
#
# La regla que se uso para hacer el remuestreo es el llenado hacia adelante, de modo que se no se usara informacion del futuro y asi seguir tratando los datos como una serie temporal.

# %% [markdown]
# ** Para los Leones **

# %%
#diasLosLeones=anulador_datosPequeños(diasLosLeones)
detectoresLosLeones=concatenadorResampler(diasLosLeones)
detectoresLosLeones.shape
# Out:
# (3241, 30)

# %% [markdown]
# ** Para Los Morados **

# %%
#diasLosMorados=anulador_datosPequeños(diasLosMorados)
detectoresLosMorados=concatenadorResampler(diasLosMorados)
detectoresLosMorados.shape
# Out:
# (3240, 30)

# %% [markdown]
# ** Para Loma Amarilla **

# %%
#diasLomaAmarilla=anulador_datosPequeños(diasLomaAmarilla)
detectoresLomaAmarilla=concatenadorResampler(diasLomaAmarilla)
detectoresLomaAmarilla.shape
# Out:
# (3240, 30)

# %% [markdown]
# ** Para Colihueco **

# %%
#diasCoihueco=anulador_datosPequeños(diasCoihueco)
diasCoihuecoDeduplicado=deduplicadorV2(diasCoihueco)
detectoresCoihueco=concatenadorResampler(diasCoihuecoDeduplicado)
detectoresCoihueco.shape
# Out:
# (3241, 30)

# %% [markdown]
# Se concatenan los datos de los detectores de forma horizontal.

# %% [markdown]
# # Leer Temperatura de la estación

# %% [markdown]
# Se cargan  los datos de una estación, y se remuestrean de modo que correspondan con la frecuencia con las que se remuestrearon los datos de los detectores. De la misma manera que con los datos de los detectores, estos tambien se remuestrearon usando la regla de llenado hacia delante.

# %%
def lecturaTemperaturaStation(ruta, detectStation):
    nombres2=["Time","Temperature"]
    temperature_Station=pd.read_csv(str(ruta), sep=" ", header=None, names=nombres2, usecols=[0, 1], index_col=None)
    temperature_Station.set_index("Time", inplace=True)
    temperature_Station.index=pd.to_datetime(temperature_Station.index, unit="s")
    temperature_Station=temperature_Station.resample("400s").ffill()
    
    first=str(detectStation.index[0])
    last=str(detectStation.index[-1])
    temperature_Station=temperature_Station.loc[first:last]
    return temperature_Station

# %%
def anulador_temperaturasBajas(temperature_Station):
    temperature_Station.loc[temperature_Station.Temperature<=0.2,"Temperature"]=None
    temperature_Station.ffill(inplace=True)
    return temperature_Station

# %%
#Leones
temperature_Leones=lecturaTemperaturaStation("/home/libardomm/auger/station/Los_Morados/wlmo_l2.dat", detectoresLosLeones)
temperature_Leones=anulador_temperaturasBajas(temperature_Leones)
temperature_Leones.loc["2014-05-09 08:46:40"]=None
temperature_Leones.loc["2014-05-09 08:53:20"]=None

temperature_Leones.ffill(inplace=True)
temperature_Leones.shape
# Out:
# (3241, 1)

# %%
#Morados
temperature_Morados=lecturaTemperaturaStation("/home/libardomm/auger/station/Los_Morados/wlmo_l2.dat", detectoresLosMorados)
temperature_Moradose=anulador_temperaturasBajas(temperature_Morados)
temperature_Morados.loc["2014-05-09 08:46:40"]=None
temperature_Morados.loc["2014-05-09 08:53:20"]=None
temperature_Morados.ffill(inplace=True)
temperature_Morados.shape
# Out:
# (3240, 1)

# %%
temperature_Morados[temperature_Morados.Temperature<2.5]
# Out:
#                      Temperature
# Time
# 2014-05-12 09:13:20        2.323
# 2014-05-12 09:20:00        2.127
# 2014-05-12 09:26:40        1.984
# 2014-05-12 09:33:20        1.909
# 2014-05-12 09:40:00        1.695
# 2014-05-12 09:46:40        1.611
# 2014-05-12 09:53:20        1.469
# 2014-05-12 10:00:00        1.469
# 2014-05-12 10:06:40        1.469
# 2014-05-12 10:13:20        1.469
# ...                          ...
# 2014-05-12 13:33:20        1.469
# 2014-05-12 13:40:00        1.469
# 2014-05-12 13:46:40        1.469
# 2014-05-12 13:53:20        1.469
# 2014-05-12 14:00:00        1.469
# 2014-05-12 14:06:40        1.469
# 2014-05-12 14:13:20        1.469
# 2014-05-12 14:20:00        1.469
# 2014-05-12 14:26:40        1.469
# 2014-05-12 14:33:20        1.469
#
# [49 rows x 1 columns]

# %%
x=temperature_Morados.loc["2014-05-09"].index
y=temperature_Morados.loc["2014-05-09"].Temperature
plt.figure(figsize=(10,10))
plt.plot(x,y)

# %%
#Loma Amarilla 
temperature_LomaAmarilla=lecturaTemperaturaStation("/home/libardomm/auger/station/Loma_Amarilla/wlam_l2.dat", detectoresLomaAmarilla)
temperature_LomaAmarilla=anulador_temperaturasBajas(temperature_LomaAmarilla)
temperature_LomaAmarilla.shape
# Out:
# (3240, 1)

# %%
#Coihueco
temperature_Coihueco=lecturaTemperaturaStation("/home/libardomm/auger/station/Coihueco/wcoi_l1.dat", detectoresCoihueco)
temperature_Coihueco=anulador_temperaturasBajas(temperature_Coihueco)
temperature_Coihueco.shape
# Out:
# (3241, 1)

# %% [markdown]
# Se toman solamente los registros de temperatura necesarios para que coincidan con el numero de registros que se tomaron en los detectores.

# %% [markdown]
# Se concatena la temperatura de la estacion con los datos de los detectores. Tambien se eliminan manualmente las filas de datos de los dias faltantes como tambien la primera fila que tiene datos anterioresl al primer dia

# %%
def preparadordeDatos(detectores_station, temp):
    data_station=pd.concat([detectores_station, temp], axis=1)
    data_station.drop(data_station.loc["2014-04-30"].index, inplace=True)
    data_station.drop(data_station.loc["2014-05-06"].index, inplace=True)
    #data_station.drop(data_station.loc["2014-05-16"].index, inplace=True)
    data_station.fillna(method="ffill", inplace=True)
    data_station.fillna(method="bfill", inplace=True)

    return data_station

# %%
def completadorDatos(data_Station):
    registrosMenosUno=len(dias)*216-1
    if data_Station.shape[0]==registrosMenosUno:
        segundos200=pd.Timedelta(seconds=400)
        data_Station.loc[data_Station.index[-1]+segundos200]=None
        data_Station.ffill(inplace=True)
    return data_Station

# %%
data_LosLeones= preparadordeDatos(detectoresLosLeones,temperature_Leones)
data_LosLeones=completadorDatos(data_LosLeones)

data_LomaAmarilla=preparadordeDatos(detectoresLomaAmarilla,temperature_LomaAmarilla)
data_LomaAmarilla=completadorDatos(data_LomaAmarilla)

data_LosMorados=preparadordeDatos(detectoresLosMorados, temperature_Morados)
data_LosMorados=completadorDatos(data_LosMorados)

data_Coihueco=preparadordeDatos(detectoresCoihueco, temperature_Coihueco)
data_Coihueco=completadorDatos(data_Coihueco)

data_LosLeones.name="Los Leones"
data_LosMorados.name="Los Morados"
data_LomaAmarilla.name="Loma Amarilla"
data_Coihueco.name="Coihueco"
print(data_LosLeones.shape)
print(data_LomaAmarilla.shape)
print(data_LosMorados.shape)
print(data_Coihueco.shape)
# Out:
# (3024, 31)
# (3024, 31)
# (3024, 31)
# (3024, 31)

# %% [markdown]
# ## 2. Machine Learning

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import  metrics
from sklearn.ensemble import RandomForestRegressor
from random import seed
from sklearn import svm

# %%
data_LomaAmarilla.index=pd.to_datetime(data_LomaAmarilla.index)
data_LomaAmarilla.index
data_LosLeones.index=pd.to_datetime(data_LosLeones.index)
data_LosLeones.index
data_Coihueco.index=pd.to_datetime(data_Coihueco.index)

# %%
    columnas=nombres2.copy()
    columnas.remove("fTime")
    columnas.remove("fLsId")
    def XySplit(data_station):


        X=data_station[columnas]
        y=data_station.Temperature
        return X,y

# %% [markdown]
# Se define cual va a ser la matriz de variables de entrada( X: datos de tanques) y el vector con los datos deseados (y: temperatura de una estacion)

# %% [markdown]
# Se define la funcion que va a permitir cortar el datos segun las estrategia que se describe a continuacion:
# * En la primera configuracion se toma algunos dias de datos consecutivos como datos de training y el dia imediatamente despues al ultimo de los dia de training se toma como test.
# * En la siguiente configuracion se corren tanto los datos de training como los de test en un dia. O en otras palabras, si se toman tres dias de training y en la anterior configuracion se tomaron los dias 1,2 y 3 como training y el dia 4 como testing, en este caso se toman los dias 2,3,4 como training y el dia 5 como testing.

# %% [markdown]
# # Tabla mejorada

# %%
indices = ["3d-1d-L","4d-1d-L","5d-1d-L","3d-1d-A","4d-1d-A","5d-1d-A"]

# %%
def crearIndice(i):
    return str(i)+"-1 dia Test-"

# %%
def selectStimator(x):
    return {
        'l': LinearRegression(),
        'r': RandomForestRegressor(n_estimators=10,random_state=42),
        's': svm.SVR(kernel="rbf")
    }.get(x, "Ingrese entre comillas l para Regresion Lineal, r para random forest  o s para SVR")

# %%
def cross_val( Trainfolds, data_stationA, data_stationB, label, option):
    plt.figure(figsize=(16,40))
    
    n=int(np.round(data_stationA.shape[0]/216))-Trainfolds
    estimador=selectStimator(option)
    regs=216
    errores=[]
    
    Xa,ya= XySplit(data_stationA) # Train
    Xb, yb= XySplit(data_stationB) # Test

    for n in range(0,n):
        f_day_n= regs*n #primer dia de entrenamiento
        l_day_n=f_day_n + (Trainfolds*regs) #ultimo dia de entrenan
        iX_train=Xa.iloc[f_day_n:l_day_n]
        iy_train=ya.iloc[f_day_n:l_day_n]

        iX_test= Xb.iloc[l_day_n: l_day_n+regs]
        iy_test=yb.iloc[l_day_n: l_day_n+regs]
        
        estimador.fit(iX_train,iy_train)
        iy_predic=estimador.predict(iX_test)
        
        plt.subplot(25,1,n+1)
        x=range(len(iy_predic))
        plt.plot(x,iy_predic, 'r--', label='Prediction')
        plt.plot(x,iy_test,  label='True')
        plt.legend(loc='upper left', frameon=False)
        plt.ylabel('Temperature(C°)')
        plt.xlabel('Registers(Every 400s)')
        plt.title(data_stationA.name+"-"+data_stationB.name+":"+label+": Run "+str(n+1), fontsize=14, fontweight='bold')

        errores.append((metrics.mean_absolute_error(iy_test,iy_predic)))
    return  np.array([np.mean(errores),np.std(errores)])

# %%
cross_val(10,data_LosLeones,data_LosLeones,"yolo","l")
# Out:
# array([ 2.68269309,  0.84024005])

# %%
# manden un vector
def tabuladorGraficador(data_stationA, data_stationB, option): 
    my_df= []

    for i in range(3,6):
        a=cross_val(i,data_stationA, data_stationB, crearIndice(i), option)
        d = {
            'indice': crearIndice(i),
            #'Mean,Standard Dev' : [a[0], a[1]] , # some formula for obtaining values
            'Mean' : a[0] , # some formula for obtaining values
            'Standard Dev' : a[1],
        }
        my_df.append(d)

    my_df = pd.DataFrame(my_df)

    my_df.set_index('indice', inplace=True)
    
    return my_df

# %%
tabuladorGraficador( data_LosMorados,data_LomaAmarilla,"s")
# Out:
#                    Mean  Standard Dev
# indice
# 3-1 dia Test-  3.684914      1.680617
# 4-1 dia Test-  3.454777      1.756891
# 5-1 dia Test-  3.479539      1.894635

# %%
tabuladorGraficador( data_LomaAmarilla,data_LosMorados,"r")
# Out:
#                    Mean  Standard Dev
# indice
# 3-1 dia Test-  2.979176      0.877862
# 4-1 dia Test-  3.199194      1.216987
# 5-1 dia Test-  3.471784      1.385225

# %%
#temp=temp.iloc[150:219]

def graficador(data_Station,numero_del_detector):
    temp=data_Station
    temp.to_csv("/home/libardomm/auger/2014/prueba_temp.csv")
    temp=pd.read_csv("/home/libardomm/auger/2014/prueba_temp.csv",index_col=0)
    temp.index=pd.to_datetime(temp.index)
    temp.columns
    plt.figure(figsize=(15,4))
    x=range(len(temp.index))
    y1=temp["fPMT[0]."+str(numero_del_detector)]
    y2=temp["fPMT[1]."+str(numero_del_detector)]
    y3=temp["fPMT[2]."+str(numero_del_detector)]
    #y4=temp["fElectT."+str(numero_del_detector)]
    y5=temp["fBatteryT[0]."+str(numero_del_detector)]
    y6=temp["fBatteryT[1]."+str(numero_del_detector)]
    plt.plot(x,y1,label="fPMT[0]")
    plt.plot(x,y2, label="fPMT[1]")
    plt.plot(x,y3, label="fPMT[2]")
    #plt.plot(x,y4, label="fElectT")
    plt.plot(x,y5, label="fBatteryT[0]")
    plt.plot(x,y6, label="fBatteryT[1]")
    plt.plot(x,temp.Temperature,'k--', label="Temperature")
    plt.legend(loc='upper left', frameon=False)
    plt.title(numero_del_detector, fontsize=14, fontweight='bold')

# %% [markdown]
# # Tabla: Panorama General

# %%
def labelStation(i):
    station=["Los Leones", "Los Morados", "Loma Amarilla", "Coihueco"]

# %%
def mean_stDv( Trainfolds, data_stationA, data_stationB, option): #columnas train, filas test
    n=int(np.round(data_stationA.shape[0]/216))-Trainfolds
    estimador=selectStimator(option)
    regs=216
    errores=[]
    
    Xa,ya= XySplit(data_stationA)
    Xb, yb= XySplit(data_stationB)

    for n in range(0,n):
        f_day_n= regs*n #primer dia de entrenamiento
        l_day_n=f_day_n + (Trainfolds*regs) #ultimo dia de entrenan
        iX_train=Xa.iloc[f_day_n:l_day_n]
        iy_train=ya.iloc[f_day_n:l_day_n]

        iX_test= Xb.iloc[l_day_n: l_day_n+regs]
        iy_test=yb.iloc[l_day_n: l_day_n+regs]
        
        estimador.fit(iX_train,iy_train)
        iy_predic=estimador.predict(iX_test)

        errores.append((metrics.mean_absolute_error(iy_test,iy_predic)))
    return  str(round(np.mean(errores),2))+"(+/- "+str(round(np.std(errores),2))+")"

# %%
def tablaPorConfiguracion(trainFold,estimador):
    data_Station_list=[data_LosLeones, data_LosMorados,data_LomaAmarilla,data_Coihueco]
    labels=["Los Leones", "Los Morados","Loma Amarilla","Coihueco"]
    my_df= []
    t=0

    for j in data_Station_list:

        d = {

            'Station': labels[t],
            'Los Leones' : mean_stDv(trainFold,data_Station_list[0],j,str(estimador)) ,
            'Los Morados' : mean_stDv(trainFold,data_Station_list[1],j,str(estimador)) ,
            'Loma Amarilla' : mean_stDv(trainFold,data_Station_list[2],j,str(estimador)) ,
            'Coihueco' : mean_stDv(trainFold,data_Station_list[3],j,str(estimador)) ,

        }
        t=t+1
        my_df.append(d)

    my_df = pd.DataFrame(my_df)

    my_df.set_index('Station', inplace=True)

    return my_df[["Los Leones","Los Morados", "Loma Amarilla","Coihueco"]]

# %%
misxticks_=("LL-LL","LL-LM","LL-LA","LL-CH")

def graficadorErrores(dt1,dt2,dt3,dt4,dt5,dt6,dt7,dt8,xticks_,stacion_train,columna):
    
    
    dt1_mean=meanDf(dt1)
    dt2_mean=meanDf(dt2)
    dt3_mean=meanDf(dt3)
    dt4_mean=meanDf(dt4)
    dt5_mean=meanDf(dt5)
    dt6_mean=meanDf(dt6)
    dt7_mean=meanDf(dt7)
    dt8_mean=meanDf(dt8)
    
    dt1_stv=deviationDf(dt1)
    dt2_stv=deviationDf(dt2)
    dt3_stv=deviationDf(dt3)
    dt4_stv=deviationDf(dt4)
    dt5_stv=deviationDf(dt5)
    dt6_stv=deviationDf(dt6)
    dt7_stv=deviationDf(dt7)
    dt8_stv=deviationDf(dt8)
    
    plt.figure(figsize=(14,7))
    ancho=0.1
    opacity = 0.9
    n=4
    indice=np.arange(1,5)
    
    plt.bar(indice,dt1_mean.iloc[:,columna], ancho,yerr=dt1_stv.iloc[:,columna], alpha=opacity,label=dt1.name)
    plt.bar(indice+ancho,dt2_mean.iloc[:,columna], ancho,yerr=dt2_stv.iloc[:,columna],alpha=opacity, label=dt2.name)
    plt.bar(indice+2*ancho,dt3_mean.iloc[:,columna], ancho,yerr=dt3_stv.iloc[:,columna],alpha=opacity, label=dt3.name)
    plt.bar(indice+3*ancho,dt4_mean.iloc[:,columna], ancho,yerr=dt4_stv.iloc[:,columna], alpha=opacity, label=dt4.name)
    plt.bar(indice+4*ancho,dt5_mean.iloc[:,columna], ancho,yerr=dt5_stv.iloc[:,columna], alpha=opacity, label=dt5.name)
    plt.bar(indice+5*ancho,dt6_mean.iloc[:,columna], ancho,yerr=dt6_stv.iloc[:,columna], alpha=opacity, label=dt6.name)
    plt.bar(indice+6*ancho,dt7_mean.iloc[:,columna], ancho,yerr=dt7_stv.iloc[:,columna], alpha=opacity, label=dt7.name)
    plt.bar(indice+7*ancho,dt8_mean.iloc[:,columna], ancho,yerr=dt8_stv.iloc[:,columna], alpha=opacity, label=dt8.name)

    plt.xticks(indice+ancho,xticks_)
    plt.xlabel("Train-Test",fontsize=12, fontweight='bold')
    plt.ylabel("Error de Predicción en grados",fontsize=12, fontweight='bold')
    plt.grid(axis="y")
    plt.title("Comparativa de errores de diferentes configuraciones de cross  validation cuando se usan \n datos de "+stacion_train+" como datos de entrenamiento.",fontsize=14, fontweight='bold')
    #plt.subtitle('bold figure suptitle', fontsize=14, fontweight='bold')
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

    plt.show()

# %%
def limpiar(dataframe):
    for i in range(dataframe.shape[0]):
        dataframe.iloc[:,i]=dataframe.iloc[:,i].str.replace("(", "").str.replace(")","").str.replace("+","").str.replace("/","").str.replace(" ","")
    return dataframe

def meanDf(dataframe):
    df=dataframe.copy()
    for i in range(dataframe.shape[0]):
        for j in range(dataframe.shape[0]):
            df.iloc[i,j]=float(dataframe.iloc[i,j].split("-")[0])
    return df


def deviationDf(dataframe):
    df=dataframe.copy()
    for i in range(dataframe.shape[0]):
        for j in range(dataframe.shape[0]):
            df.iloc[i,j]=float(dataframe.iloc[i,j].split("-")[1])
    return df

# %%
graficadorErrores(dt1=l3,dt2=l4,dt3=l5,dt4=l6,dt5=l7,dt6=l8,dt7=l9, dt8=l10,xticks_=("LL-LL","LL-LM","LL-LA","LL-CH"),stacion_train="Los Leones",columna=0)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## 3 Train - 1 Test

# %%
l3=tablaPorConfiguracion(3,"l")
l3.name="3d Train"
l3
# Out:
#                      Los Leones      Los Morados   Loma Amarilla  \
# Station
# Los Leones       2.27(+/- 0.82)   3.51(+/- 1.58)  14.0(+/- 7.68)
# Los Morados       7.28(+/- 4.2)   1.65(+/- 0.74)  6.81(+/- 5.17)
# Loma Amarilla    8.16(+/- 4.69)  10.78(+/- 6.55)  1.71(+/- 0.98)
# Coihueco       16.71(+/- 10.74)   8.79(+/- 3.06)  11.23(+/- 7.8)
#
#                      Coihueco
# Station
# Los Leones     9.17(+/- 4.68)
# Los Morados    6.96(+/- 3.51)
# Loma Amarilla  5.92(+/- 3.95)
# Coihueco       1.84(+/- 0.57)

# %% [markdown]
# ## 4 Train - 1 Test

# %%
l4=tablaPorConfiguracion(4,"l")
l4.name="4d Train"
l4
# Out:
#                     Los Leones      Los Morados    Loma Amarilla  \
# Station
# Los Leones      2.37(+/- 0.77)   3.43(+/- 1.78)  13.16(+/- 7.54)
# Los Morados     8.23(+/- 5.09)   1.56(+/- 0.82)    5.97(+/- 4.2)
# Loma Amarilla    9.0(+/- 5.21)  11.32(+/- 6.17)    1.4(+/- 0.69)
# Coihueco       12.99(+/- 7.71)   8.48(+/- 3.67)  12.37(+/- 4.81)
#
#                      Coihueco
# Station
# Los Leones     9.62(+/- 5.64)
# Los Morados    6.04(+/- 3.66)
# Loma Amarilla  4.99(+/- 3.36)
# Coihueco        1.57(+/- 0.7)

# %% [markdown]
# ## 5 Train - 1 Test

# %%
l5=tablaPorConfiguracion(5,"l")
l5.name="5d Train"
l5
# Out:
#                     Los Leones      Los Morados    Loma Amarilla  \
# Station
# Los Leones       2.43(+/- 0.8)   4.57(+/- 1.95)  12.76(+/- 6.92)
# Los Morados      8.3(+/- 4.99)   1.58(+/- 0.78)   5.38(+/- 3.68)
# Loma Amarilla   8.14(+/- 4.24)  11.07(+/- 5.14)   1.31(+/- 0.33)
# Coihueco       11.14(+/- 5.16)   8.11(+/- 3.72)  12.95(+/- 4.28)
#
#                       Coihueco
# Station
# Los Leones     11.58(+/- 6.29)
# Los Morados      7.11(+/- 3.5)
# Loma Amarilla    4.65(+/- 2.2)
# Coihueco        1.57(+/- 0.66)

# %% [markdown]
# ## 6 Train - 1 Test

# %%
l6=tablaPorConfiguracion(6,"l")
l6.name="6d Train"
l6
# Out:
#                    Los Leones      Los Morados    Loma Amarilla  \
# Station
# Los Leones       2.2(+/- 0.9)   4.45(+/- 2.74)  11.36(+/- 6.27)
# Los Morados     9.93(+/- 3.8)   1.54(+/- 0.61)   5.22(+/- 3.42)
# Loma Amarilla  9.02(+/- 2.28)  11.58(+/- 5.65)    1.3(+/- 0.42)
# Coihueco        10.2(+/- 5.9)   6.55(+/- 4.53)  12.68(+/- 4.39)
#
#                       Coihueco
# Station
# Los Leones     13.83(+/- 6.27)
# Los Morados     8.79(+/- 4.33)
# Loma Amarilla   4.79(+/- 1.24)
# Coihueco        1.36(+/- 0.55)

# %% [markdown]
# ## 7 Train - 1 Test

# %%
l7=tablaPorConfiguracion(7,"l")
l7.name="7d Train"
l7
# Out:
#                     Los Leones      Los Morados    Loma Amarilla  \
# Station
# Los Leones       1.96(+/- 0.8)   4.86(+/- 2.37)  10.24(+/- 5.22)
# Los Morados    11.59(+/- 3.57)   1.49(+/- 0.59)   4.68(+/- 1.78)
# Loma Amarilla     9.4(+/- 2.6)  10.95(+/- 5.93)   1.36(+/- 0.53)
# Coihueco        9.21(+/- 4.65)   6.82(+/- 4.64)   11.94(+/- 5.2)
#
#                       Coihueco
# Station
# Los Leones     15.58(+/- 5.27)
# Los Morados    10.66(+/- 5.75)
# Loma Amarilla   6.05(+/- 2.66)
# Coihueco        1.42(+/- 0.56)

# %% [markdown]
# ## 8 Train - 1 Test

# %%
l8=tablaPorConfiguracion(8,"l")
l8.name="8d Train"
l8
# Out:
#                     Los Leones      Los Morados   Loma Amarilla  \
# Station
# Los Leones      2.03(+/- 0.87)   4.35(+/- 1.76)  9.67(+/- 4.48)
# Los Morados    11.89(+/- 2.97)   1.59(+/- 0.72)  4.26(+/- 1.71)
# Loma Amarilla   9.74(+/- 3.69)  10.61(+/- 5.11)  1.18(+/- 0.44)
# Coihueco        9.47(+/- 4.36)   8.12(+/- 5.52)  9.48(+/- 6.29)
#
#                       Coihueco
# Station
# Los Leones     17.26(+/- 4.05)
# Los Morados    12.93(+/- 5.43)
# Loma Amarilla    6.38(+/- 2.8)
# Coihueco        1.43(+/- 0.36)

# %% [markdown]
# ## 9 Train - 1 Test

# %%
l9=tablaPorConfiguracion(9,"l")
l9.name="9d Train"
l9
# Out:
#                     Los Leones     Los Morados   Loma Amarilla  \
# Station
# Los Leones      2.12(+/- 0.98)  3.71(+/- 2.37)   9.97(+/- 3.9)
# Los Morados    11.97(+/- 3.59)   2.01(+/- 0.7)  4.11(+/- 2.06)
# Loma Amarilla  10.06(+/- 3.39)  9.85(+/- 4.11)  1.34(+/- 0.28)
# Coihueco       10.55(+/- 3.25)  9.83(+/- 6.31)   7.78(+/- 5.6)
#
#                       Coihueco
# Station
# Los Leones     17.49(+/- 3.54)
# Los Morados    14.35(+/- 5.36)
# Loma Amarilla   6.68(+/- 3.12)
# Coihueco        1.33(+/- 0.29)

# %% [markdown]
# ## 10 Train - 1 Test

# %%
l10=tablaPorConfiguracion(10,"l")
l10.name="10d Train"
l10
# Out:
#                     Los Leones      Los Morados    Loma Amarilla  \
# Station
# Los Leones      2.68(+/- 0.84)   5.84(+/- 2.73)  10.27(+/- 3.46)
# Los Morados     12.0(+/- 3.16)   2.34(+/- 0.71)   3.46(+/- 2.04)
# Loma Amarilla   9.98(+/- 2.43)    9.1(+/- 3.79)   1.51(+/- 0.29)
# Coihueco       12.77(+/- 3.07)  11.22(+/- 6.04)   4.76(+/- 2.66)
#
#                       Coihueco
# Station
# Los Leones     17.25(+/- 2.48)
# Los Morados     14.8(+/- 3.92)
# Loma Amarilla   5.43(+/- 2.32)
# Coihueco        1.35(+/- 0.21)

# %%
l3=limpiar(l3)
l4=limpiar(l4)
l5=limpiar(l5)
l6=limpiar(l6)
l7=limpiar(l7)
l8=limpiar(l8)
l9=limpiar(l9)
l10=limpiar(l10)

# %%
graficadorErrores(dt1=l3,dt2=l4,dt3=l5,dt4=l6,dt5=l7,dt6=l8,dt7=l9, dt8=l10,xticks_=("LL-LL","LL-LM","LL-LA","LL-CH"),stacion_train="Los Leones",columna=0)

# %%
graficadorErrores(dt1=l3,dt2=l4,dt3=l5,dt4=l6,dt5=l7,dt6=l8,dt7=l9, dt8=l10,xticks_=("LM-LL","LM-LM","LM-LA","LM-CH"),stacion_train="Los Morados",columna=1)

# %%
graficadorErrores(dt1=l3,dt2=l4,dt3=l5,dt4=l6,dt5=l7,dt6=l8,dt7=l9, dt8=l10,xticks_=("LA-LL","LA-LM","LA-LA","LA-CH"),stacion_train="Loma Amarilla",columna=2)

# %%
graficadorErrores(dt1=l3,dt2=l4,dt3=l5,dt4=l6,dt5=l7,dt6=l8,dt7=l9, dt8=l10,xticks_=("CH-LL","CH-LM","CH-LA","CH-CH"),stacion_train="Coihueco",columna=3)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## 3 Train - 1 Test

# %%
r3=tablaPorConfiguracion(3,"r")
r3.name="3d Train"
r3
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.41(+/- 1.03)  2.99(+/- 1.27)  3.35(+/- 1.61)  2.25(+/- 0.75)
# Los Morados    2.07(+/- 1.13)  2.18(+/- 1.35)  2.98(+/- 0.88)  2.23(+/- 0.76)
# Loma Amarilla  2.71(+/- 1.39)  2.89(+/- 1.77)  1.93(+/- 0.71)  3.03(+/- 1.28)
# Coihueco       2.75(+/- 1.01)   2.71(+/- 1.2)  2.92(+/- 1.02)  2.36(+/- 0.76)

# %% [markdown]
# ## 4 Train - 1 Test

# %%
r4=tablaPorConfiguracion(4,"r")
r4.name="4d Train"
r4
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones      2.42(+/- 1.0)  3.23(+/- 1.25)   3.58(+/- 1.6)  2.28(+/- 0.92)
# Los Morados    2.07(+/- 1.34)  2.04(+/- 1.27)   3.2(+/- 1.22)  2.48(+/- 1.07)
# Loma Amarilla  2.76(+/- 1.42)  2.87(+/- 1.67)  1.81(+/- 0.79)   3.1(+/- 1.17)
# Coihueco       2.68(+/- 1.22)  3.05(+/- 1.21)  3.48(+/- 1.67)  2.26(+/- 1.02)

# %% [markdown]
# ## 5 Train - 1 Test

# %%
r5=tablaPorConfiguracion(5,"r")
r5.name="5d Train"
r5
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.69(+/- 1.28)  3.44(+/- 1.29)  4.23(+/- 2.07)  2.57(+/- 1.21)
# Los Morados    2.14(+/- 1.36)   2.16(+/- 1.4)  3.47(+/- 1.39)  2.76(+/- 1.31)
# Loma Amarilla  2.41(+/- 1.18)  2.85(+/- 1.63)  1.86(+/- 0.94)  3.13(+/- 1.42)
# Coihueco       2.73(+/- 1.13)  2.71(+/- 1.17)  3.37(+/- 1.69)  2.26(+/- 1.06)

# %% [markdown]
# ## 6 Train - 1 Test

# %%
r6=tablaPorConfiguracion(6,"r")
r6.name="6d Train"
r6
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.38(+/- 1.19)  3.48(+/- 0.79)  4.81(+/- 2.07)   2.58(+/- 1.4)
# Los Morados    1.99(+/- 1.26)  2.03(+/- 1.24)  3.86(+/- 1.58)  2.97(+/- 1.23)
# Loma Amarilla   2.43(+/- 1.1)  2.71(+/- 1.53)  1.85(+/- 1.07)  3.29(+/- 1.43)
# Coihueco       2.44(+/- 1.02)   3.1(+/- 1.38)  3.74(+/- 2.32)  1.88(+/- 0.94)

# %% [markdown]
# ## 7 Train - 1 Test

# %%
r7=tablaPorConfiguracion(7,"r")
r7.name="7d Train"
r7
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.43(+/- 1.27)  3.44(+/- 0.81)   4.55(+/- 2.1)  2.87(+/- 1.41)
# Los Morados    2.08(+/- 1.28)  2.18(+/- 1.19)  4.12(+/- 1.65)  2.99(+/- 1.38)
# Loma Amarilla  2.47(+/- 1.12)  2.69(+/- 1.45)  1.83(+/- 0.97)  3.42(+/- 1.32)
# Coihueco       2.47(+/- 0.89)  3.27(+/- 1.29)  3.55(+/- 1.78)  1.79(+/- 0.77)

# %% [markdown]
# ## 8 Train - 1 Test

# %%
r8=tablaPorConfiguracion(8,"r")
r8.name="8d Train"
r8
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones      2.5(+/- 1.16)   3.0(+/- 0.63)  4.66(+/- 1.91)  2.52(+/- 1.14)
# Los Morados    2.25(+/- 1.37)  2.38(+/- 1.06)  4.12(+/- 1.75)  3.06(+/- 0.97)
# Loma Amarilla   2.6(+/- 1.28)  3.13(+/- 1.68)  1.91(+/- 0.88)  3.61(+/- 1.49)
# Coihueco       2.59(+/- 0.92)   3.02(+/- 1.3)   3.35(+/- 1.4)  1.72(+/- 0.63)

# %% [markdown]
# ## 9 Train - 1 Test

# %%
r9=tablaPorConfiguracion(9,"r")
r9.name="9d Train"
r9
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.51(+/- 0.91)  2.79(+/- 0.65)   4.57(+/- 2.0)  2.74(+/- 1.29)
# Los Morados    2.37(+/- 1.17)    2.4(+/- 1.1)  4.16(+/- 1.88)  2.81(+/- 1.21)
# Loma Amarilla  2.95(+/- 1.08)  3.19(+/- 1.43)  1.82(+/- 0.62)  3.78(+/- 1.23)
# Coihueco       2.82(+/- 0.88)  3.42(+/- 1.08)  2.99(+/- 1.26)  1.93(+/- 0.65)

# %% [markdown]
# ## 10 Train - 1 Test

# %%
r10=tablaPorConfiguracion(10,"r")
r10.name="10d Train"
r10
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.81(+/- 1.11)  2.65(+/- 0.87)  4.15(+/- 1.17)   2.86(+/- 1.3)
# Los Morados    2.79(+/- 1.37)  2.54(+/- 0.88)  3.88(+/- 1.55)  2.64(+/- 0.96)
# Loma Amarilla  3.18(+/- 0.62)  3.62(+/- 0.62)  2.11(+/- 0.58)   3.96(+/- 0.9)
# Coihueco       2.33(+/- 0.43)  3.17(+/- 1.13)  2.12(+/- 0.41)  1.94(+/- 0.66)

# %%
r3=limpiar(r3)
r4=limpiar(r4)
r5=limpiar(r5)
r6=limpiar(r6)
r7=limpiar(r7)
r8=limpiar(r8)
r9=limpiar(r9)
r10=limpiar(r10)

# %%
graficadorErrores(dt1=r3,dt2=r4,dt3=r5,dt4=r6,dt5=r7,dt6=r8,dt7=r9, dt8=r10,xticks_=("LL-LL","LL-LM","LL-LA","LL-CH"),stacion_train="Los Leones",columna=0)

# %%
graficadorErrores(dt1=r3,dt2=r4,dt3=r5,dt4=r6,dt5=r7,dt6=r8,dt7=r9, dt8=r10,xticks_=("LM-LL","LM-LM","LM-LA","LM-CH"),stacion_train="Los Morados",columna=1)

# %%
graficadorErrores(dt1=r3,dt2=r4,dt3=r5,dt4=r6,dt5=r7,dt6=r8,dt7=r9, dt8=r10,xticks_=("LA-LL","LA-LM","LA-LA","LA-CH"),stacion_train="Loma Amarilla",columna=2)

# %%
graficadorErrores(dt1=r3,dt2=r4,dt3=r5,dt4=r6,dt5=r7,dt6=r8,dt7=r9, dt8=r10,xticks_=("CH-LL","CH-LM","CH-LA","CH-CH"),stacion_train="Coihueco",columna=3)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Support Vector Regression

# %% [markdown]
# ## 3 Train - 1 Test

# %%
s3=tablaPorConfiguracion(3,"s")
s3.name="3d Train"
s3
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.76(+/- 1.68)  3.27(+/- 1.37)  4.11(+/- 1.14)  3.35(+/- 1.12)
# Los Morados    3.16(+/- 1.41)  2.34(+/- 1.79)  3.65(+/- 0.95)  3.18(+/- 1.02)
# Loma Amarilla  4.47(+/- 1.24)  3.68(+/- 1.68)  2.52(+/- 1.76)    4.1(+/- 1.4)
# Coihueco       3.97(+/- 1.18)  3.75(+/- 1.34)   4.28(+/- 1.4)  2.51(+/- 0.89)

# %% [markdown]
# ## 4 Train - 1 Test

# %%
s4=tablaPorConfiguracion(4,"s")
s4.name="4d Train"
s4
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.67(+/- 1.79)  3.17(+/- 1.52)   4.24(+/- 1.3)  3.32(+/- 1.15)
# Los Morados    2.94(+/- 1.53)  2.15(+/- 1.88)  3.68(+/- 1.14)  3.01(+/- 1.11)
# Loma Amarilla  4.35(+/- 1.42)  3.45(+/- 1.76)  2.33(+/- 1.86)  4.08(+/- 1.39)
# Coihueco       3.97(+/- 1.45)  3.77(+/- 1.57)   4.6(+/- 1.86)  2.23(+/- 1.04)

# %% [markdown]
# ## 5 Train - 1 Test

# %%
s5=tablaPorConfiguracion(5,"s")
s5.name="5d Train"
s5
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.61(+/- 1.49)  3.13(+/- 1.36)  4.39(+/- 1.58)   3.46(+/- 1.3)
# Los Morados    2.93(+/- 1.59)   1.9(+/- 1.43)  3.76(+/- 1.26)  3.17(+/- 1.24)
# Loma Amarilla  4.45(+/- 1.55)  3.48(+/- 1.89)   2.29(+/- 1.8)  4.25(+/- 1.53)
# Coihueco       3.93(+/- 1.45)  3.72(+/- 1.57)  4.63(+/- 1.99)  2.18(+/- 1.13)

# %% [markdown]
# ## 6 Train - 1 Test

# %%
s6=tablaPorConfiguracion(6,"s")
s6.name="6d Train"
s6
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones      2.3(+/- 1.38)  3.13(+/- 1.43)  4.49(+/- 1.77)  3.43(+/- 1.41)
# Los Morados    2.85(+/- 1.56)  1.76(+/- 1.22)  3.91(+/- 1.56)   3.17(+/- 1.3)
# Loma Amarilla   4.3(+/- 1.58)  3.32(+/- 1.91)  2.17(+/- 1.84)  4.13(+/- 1.49)
# Coihueco       4.01(+/- 1.65)  3.79(+/- 1.82)  4.79(+/- 2.16)  1.78(+/- 1.04)

# %% [markdown]
# ## 7 Train - 1 Test

# %%
s7=tablaPorConfiguracion(7,"s")
s7.name="7d Train"
s7
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.34(+/- 1.36)   3.19(+/- 1.5)  4.61(+/- 2.01)  3.52(+/- 1.64)
# Los Morados    2.95(+/- 1.61)  1.89(+/- 1.14)  4.11(+/- 1.82)  3.36(+/- 1.46)
# Loma Amarilla  4.45(+/- 1.71)  3.51(+/- 2.16)  2.45(+/- 2.05)  4.34(+/- 1.67)
# Coihueco       3.96(+/- 1.76)  3.83(+/- 1.88)   4.87(+/- 2.2)  1.91(+/- 1.13)

# %% [markdown]
# ## 8 Train - 1 Test

# %%
s8=tablaPorConfiguracion(8,"s")
s8.name="8d Train"
s8
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.37(+/- 1.32)  3.09(+/- 1.34)  4.67(+/- 1.93)  3.54(+/- 1.62)
# Los Morados    2.97(+/- 1.64)  1.81(+/- 0.97)   4.13(+/- 1.7)  3.42(+/- 1.39)
# Loma Amarilla  4.49(+/- 1.69)  3.59(+/- 2.16)   2.5(+/- 2.11)  4.44(+/- 1.75)
# Coihueco       3.83(+/- 1.74)  3.63(+/- 1.73)  4.63(+/- 2.06)  1.96(+/- 1.07)

# %% [markdown]
# ## 9 Train - 1 Test

# %%
s9=tablaPorConfiguracion(9,"s")
s9.name="9d Train"
s9
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones      2.47(+/- 1.1)  3.31(+/- 1.21)   4.84(+/- 2.0)   3.85(+/- 1.6)
# Los Morados    2.99(+/- 1.67)  1.97(+/- 0.91)  4.15(+/- 1.83)  3.61(+/- 1.42)
# Loma Amarilla   4.7(+/- 1.66)  3.79(+/- 1.91)   2.56(+/- 1.9)  4.73(+/- 1.73)
# Coihueco       3.86(+/- 1.95)  3.79(+/- 1.93)  4.54(+/- 2.22)   2.0(+/- 1.14)

# %% [markdown]
# ## 9 Train - 1 Test

# %%
s10=tablaPorConfiguracion(10,"s")
s10.name="10d Train"
s10
# Out:
#                    Los Leones     Los Morados   Loma Amarilla        Coihueco
# Station
# Los Leones     2.74(+/- 1.09)   3.49(+/- 1.3)  4.68(+/- 2.07)  4.05(+/- 1.74)
# Los Morados    2.94(+/- 1.74)   2.3(+/- 0.93)   4.0(+/- 1.97)  3.67(+/- 1.57)
# Loma Amarilla  4.99(+/- 1.81)  4.33(+/- 1.69)  2.97(+/- 1.95)  5.16(+/- 1.71)
# Coihueco       3.26(+/- 1.37)  3.17(+/- 1.58)   3.8(+/- 1.46)  2.09(+/- 1.21)

# %%
s3=limpiar(s3)
s4=limpiar(s4)
s5=limpiar(s5)
s6=limpiar(s6)
s7=limpiar(s7)
s8=limpiar(s8)
s9=limpiar(s9)
s10=limpiar(s10)

# %%
graficadorErrores(dt1=s3,dt2=s4,dt3=s5,dt4=s6,dt5=s7,dt6=s8,dt7=s9, dt8=s10,xticks_=("LL-LL","LL-LM","LL-LA","LL-CH"),stacion_train="Los Leones",columna=0)

# %%
graficadorErrores(dt1=s3,dt2=s4,dt3=s5,dt4=s6,dt5=s7,dt6=s8,dt7=s9, dt8=s10,xticks_=("LM-LL","LM-LM","LM-LA","LM-CH"),stacion_train="Los Morados",columna=1)

# %%
graficadorErrores(dt1=s3,dt2=s4,dt3=s5,dt4=s6,dt5=s7,dt6=s8,dt7=s9, dt8=s10,xticks_=("LA-LL","LA-LM","LA-LA","LA-CH"),stacion_train="Loma Amarilla",columna=2)

# %%
graficadorErrores(dt1=s3,dt2=s4,dt3=s5,dt4=s6,dt5=s7,dt6=s8,dt7=s9, dt8=s10,xticks_=("CH-LL","CH-LM","CH-LA","CH-CH"),stacion_train="Coihueco",columna=3)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------
# # -------------------------------------------------------------------------------------------------------------

# %%
def mean_stDv4_Statations( Trainfolds, data_station1, data_station2,data_station3,data_station4, option):
    n=int(np.round(data_station1.shape[0]/216))-Trainfolds
    estimador=selectStimator(option)
    regs=216
    errores=[]
    
    X1,y1= XySplit(data_station1) # X train
    X2, y2= XySplit(data_station2)# y train
    X3,y3= XySplit(data_station3)#  X test
    X4, y4= XySplit(data_station4)# y test

    for n in range(0,n):
        f_day_n= regs*n #primer dia de entrenamiento
        l_day_n=f_day_n + (Trainfolds*regs) #ultimo dia de entrenan
        
        iX_train=X1.iloc[f_day_n:l_day_n]
        iy_train=y2.iloc[f_day_n:l_day_n]

        iX_test= X3.iloc[l_day_n: l_day_n+regs]
        iy_test=y4.iloc[l_day_n: l_day_n+regs]
        
        estimador.fit(iX_train,iy_train)
        iy_predic=estimador.predict(iX_test)

        errores.append((metrics.mean_absolute_error(iy_test,iy_predic)))
    return  str(round(np.mean(errores),2))+"(+/- "+str(round(np.std(errores),2))+")"

# %%
def Combinaciones(trainFold,estimador):
    dsl=[data_LosLeones, data_LosMorados,data_LomaAmarilla,data_Coihueco]
    labels=["X=LL y=LL", "X=LL y=LM","X=LL y=LA","X=LL y=CH",
            "X=LM y=LL", "X=LM y=LM","X=LM y=LA","X=LM y=CH",
            "X=LA y=LL", "X=LA y=LM","X=LA y=LA","X=LA y=CH",
            "X=CH y=LL", "X=CH y=LM","X=CH y=LA","X=CH y=CH"]
    my_df= []
    t=0
    for i in dsl:
        for j in dsl:

            d = {
                'Combinaciones': labels[t],
                'X=LL y=LL' : mean_stDv4_Statations(trainFold,dsl[0],dsl[0],i,j,estimador) ,
                'X=LL y=LM' : mean_stDv4_Statations(trainFold,dsl[0],dsl[1],i,j,estimador) ,
                'X=LL y=LA' : mean_stDv4_Statations(trainFold,dsl[0],dsl[2],i,j,estimador) ,
                'X=LL y=CH' : mean_stDv4_Statations(trainFold,dsl[0],dsl[3],i,j,estimador) ,
                'X=LM y=LL' : mean_stDv4_Statations(trainFold,dsl[1],dsl[0],i,j,estimador) ,
                'X=LM y=LM' : mean_stDv4_Statations(trainFold,dsl[1],dsl[1],i,j,estimador) ,
                'X=LM y=LA' : mean_stDv4_Statations(trainFold,dsl[1],dsl[2],i,j,estimador) ,
                'X=LM y=CH' : mean_stDv4_Statations(trainFold,dsl[1],dsl[3],i,j,estimador) ,
                'X=LA y=LL' : mean_stDv4_Statations(trainFold,dsl[2],dsl[0],i,j,estimador) ,
                'X=LA y=LM' : mean_stDv4_Statations(trainFold,dsl[2],dsl[1],i,j,estimador) ,
                'X=LA y=LA' : mean_stDv4_Statations(trainFold,dsl[2],dsl[2],i,j,estimador) ,
                'X=LA y=CH' : mean_stDv4_Statations(trainFold,dsl[2],dsl[3],i,j,estimador) ,
                'X=CH y=LL' : mean_stDv4_Statations(trainFold,dsl[3],dsl[0],i,j,estimador) ,
                'X=CH y=LM' : mean_stDv4_Statations(trainFold,dsl[3],dsl[1],i,j,estimador) ,
                'X=CH y=LA' : mean_stDv4_Statations(trainFold,dsl[3],dsl[2],i,j,estimador) ,
                'X=CH y=CH' : mean_stDv4_Statations(trainFold,dsl[3],dsl[3],i,j,estimador) ,

            }
            t=t+1
            my_df.append(d)

    my_df = pd.DataFrame(my_df)

    my_df.set_index('Combinaciones', inplace=True)
    return my_df[labels]

# %% [markdown]
# # Linear Regression

# %%
Combinaciones(8,"l").to_csv("/home/libardomm/auger/2014/datasets/c4l.csv")                                                                                                      
c4l=pd.read_csv("/home/libardomm/auger/2014/datasets/c4l.csv")

# %%
c4l=pd.read_csv("/home/libardomm/auger/2014/datasets/c4l.csv")
c4l

# %% [markdown]
# # Random Forest

# %%
Combinaciones(11,"r").to_csv("/home/libardomm/auger/2014/datasets/c11r.csv")

# %%
c4r=pd.read_csv("/home/libardomm/auger/2014/datasets/c11r.csv")
c4r

# %% [markdown]
# #  XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# #  XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %% [markdown]
# # Feature Importance

# %%
def cross_val_featureImportance( Trainfolds, data_stationA, data_stationB, label, option):
    #plt.figure(figsize=(16,40))
    
    n=int(np.round(data_stationA.shape[0]/216))-Trainfolds
    estimador=selectStimator(option)
    regs=216
    errores=[]
    features=[]
    
    Xa,ya= XySplit(data_stationA) # Train
    Xb, yb= XySplit(data_stationB) # Test

    for n in range(0,n):
        plt.figure(figsize=(16,40))
        f_day_n= regs*n #primer dia de entrenamiento
        l_day_n=f_day_n + (Trainfolds*regs) #ultimo dia de entrenan
        iX_train=Xa.iloc[f_day_n:l_day_n]
        iy_train=ya.iloc[f_day_n:l_day_n]

        iX_test= Xb.iloc[l_day_n: l_day_n+regs]
        iy_test=yb.iloc[l_day_n: l_day_n+regs]
        
        estimador.fit(iX_train,iy_train)
        iy_predic=estimador.predict(iX_test)
        importance=estimador.feature_importances_
        indices = np.argsort(importance)[::-1]
        
        #Plot Feature Importance
        plt.subplot(17,1,n+1)
        plt.title("Feature importances")
        plt.bar(range(iX_train.shape[1]), importance[indices],color="r", align="center")
        plt.ylabel('Importance')
        plt.xlabel('104 Atributos')
        plt.show()
        
        #Plot prediction vs True value of temperature
        plt.figure(figsize=(16,40))
        plt.subplot(17,1,n+1)
        x=range(len(iy_predic))
        plt.plot(x,iy_predic, 'r--', label='Prediction')
        plt.plot(x,iy_test,  label='True')
        plt.legend(loc='upper left', frameon=False)
        plt.ylabel('Temperature(C°)')
        plt.xlabel('Registers(Every 400s)')
        plt.title(data_stationA.name+"-"+data_stationB.name+":"+label+": Run "+str(n+1), fontsize=14, fontweight='bold')
        
        


        errores.append((metrics.mean_absolute_error(iy_test,iy_predic)))
    
    return  np.array([np.mean(errores),np.std(errores)])

# %%
cross_val_featureImportance(3,data_LosLeones,data_LomaAmarilla,"yolo","r")
